# %% [markdown]
# # Chapter 80: Diffusion Models (DDPM) from Scratch

# %% [markdown]
# ## Learning Objectives\n- Implement forward diffusion schedule\n- Train a noise predictor per timestep\n- Sample via reverse denoising chain

# %%
# !python3 2.ddpm_1d_from_scratch.py
