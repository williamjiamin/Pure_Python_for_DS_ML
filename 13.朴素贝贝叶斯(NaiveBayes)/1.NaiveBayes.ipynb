# %% [markdown]
# Created by william from lexueoude.com. 更多正版技术视频讲解，公众号 1.乐学偶得（lexueoude）2.乐学FinTech (LoveShareFinTech)
#
#
# 邮件分类问题：

# %%
from IPython.display import Image
Image(filename='1.NaiveBayes.png')

# %%
from IPython.display import Image
Image(filename='1.2.NaiveBayes.png')

# %%
from IPython.display import Image
Image(filename='1.3.NaiveBayes.png')

# %%
from IPython.display import Image
Image(filename='1.4.NaiveBayes.png')

# %%
N = (12/17)*(5/11)*(3/11)
S = (5/17)*(2/7)*(1/7)

print(N)
print(S)
# Out:
# 0.08750607681088964
# 0.012004801920768306

# %%
from IPython.display import Image
Image(filename='1.5.NaiveBayes.png')

# %% [markdown]
# 如果遇到样本里面有0的情况，可以通过添加alpha进行解决。

# %%
from IPython.display import Image
Image(filename='1.6.NaiveBayes.png')

# %%
from IPython.display import Image
Image(filename='1.7.NaiveBayes.png')

# %%
N = (12/17)*((1/15)**4)*(3/15)
S = (5/17)*((5/11)**4)*(1/11)

print(N)
print(S)

print(S > N)
# Out:
# 2.788671023965142e-06
# 0.0011413994909175646
# True
