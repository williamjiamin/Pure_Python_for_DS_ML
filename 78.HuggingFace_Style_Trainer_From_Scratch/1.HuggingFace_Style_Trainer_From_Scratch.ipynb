# %% [markdown]
# # Chapter 78: HuggingFace-Style Trainer from Scratch

# %% [markdown]
# ## Learning Objectives\n- Implement AdamW in pure Python\n- Use warmup + cosine schedule\n- Apply gradient clipping and early stopping

# %%
# !python3 2.hf_style_trainer_demo.py
