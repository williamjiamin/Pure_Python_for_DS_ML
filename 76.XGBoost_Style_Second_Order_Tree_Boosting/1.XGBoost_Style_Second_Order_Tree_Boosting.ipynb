# %% [markdown]
# # Chapter 76: XGBoost-Style Second-Order Tree Boosting

# %% [markdown]
# ## Learning Objectives\n- Implement second-order boosting with gradients + Hessians\n- Compute split gain with regularization\n- Compare first-order vs second-order convergence

# %%
# Run the full script from notebook\n!python3 2.xgboost_style_second_order_boosting.py
