# %% [markdown]
# Created by william from lexueoude.com.
# 更多正版技术视频讲解，公众号 1.乐学偶得（lexueoude）2.乐学FinTech (LoveShareFinTech)

# %%
from IPython.display import Image
from math import sqrt
Image(filename='1.1人工神经网络.png')

# %% [markdown]
# rectifier其实就是一种模仿生物的激活机制的函数
# （activation function）
#
# 常见的激活函数：
# https://en.wikipedia.org/wiki/Rectifier_(neural_networks)#Gaussian_Error_Linear_Unit_(GELU)

# %%
from IPython.display import Image
Image(filename='1.2人工神经网络.png')

# %% [markdown]
# softplus:
#
# $${\displaystyle f(x)=\ln(1+e^{x})}$$<br>
#
#
# sigmoid:
# $${\displaystyle f(x)={\frac {e^{x}}{1+e^{x}}}}$$
#
#
# ReLU:
# $${\displaystyle f(x)={\begin{cases}x&{\text{if }}x>0,\\0&{\text{otherwise}}.\end{cases}}}$$<br>
#
# $${\displaystyle f(x)=\max(x,0)}$$

# %%
from IPython.display import Image
Image(filename='1.3人工神经网络.png')

# %%
import math

softplus = math.log(1+math.exp(1.29))

print(softplus)
# Out:
# 1.5331585349551082

# %%
sigmoid =math.exp(2.14)/(1 + math.exp(2.14))
print(sigmoid)
# Out:
# 1.9147235064218293

# %%
ReLU = max(2.14,0)

print(ReLU)
# Out:
# 2.14

# %%
0.24*(-1.30)
# Out:
# -0.312

# %%
1.53*2.28
# Out:
# 3.4884

# %%
3.48+(-2.93)-0.58
# Out:
# -0.030000000000000138

# %%
from IPython.display import Image
Image(filename='1.4人工神经网络.png')

# %%
from IPython.display import Image
Image(filename='1.5人工神经网络.png')

# %%
from IPython.display import Image
Image(filename='1.6人工神经网络.png')

# %%
from IPython.display import Image
Image(filename='1.7人工神经网络.png')

# %%
from IPython.display import Image
Image(filename='1.8人工神经网络.png')

# %%
from IPython.display import Image
Image(filename='1.9人工神经网络.png')

# %%
from IPython.display import Image
Image(filename='1.10人工神经网络.png')

# %%
from IPython.display import Image
Image(filename='1.11人工神经网络.png')

# %%
from IPython.display import Image
Image(filename='1.12人工神经网络.png')

# %%
from IPython.display import Image
Image(filename='1.13人工神经网络.png')

# %%
from IPython.display import Image
Image(filename='1.14人工神经网络.png')

# %%
from random import seed
from random import random


def initialize_our_neural_network(n_inputs,n_hidden,n_outputs):
    neural_network = list()
    hidden_layer = [{'weights':[random() for i in range(n_inputs +1)]} for i in range(n_hidden)]
    neural_network.append(hidden_layer)
    output_layer = [{'weights':[random() for i in range(n_hidden +1)]} for i in range(n_outputs)]
    neural_network.append(output_layer)

    return neural_network
