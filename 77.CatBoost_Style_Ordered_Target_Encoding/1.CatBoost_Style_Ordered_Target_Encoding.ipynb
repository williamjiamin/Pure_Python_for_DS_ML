# %% [markdown]
# # Chapter 77: CatBoost-Style Ordered Target Encoding

# %% [markdown]
# ## Learning Objectives\n- Implement leakage-safe category encoding\n- Compare leaky vs ordered encoding behavior\n- Measure generalization gap

# %%
# !python3 2.ordered_target_encoding_demo.py
