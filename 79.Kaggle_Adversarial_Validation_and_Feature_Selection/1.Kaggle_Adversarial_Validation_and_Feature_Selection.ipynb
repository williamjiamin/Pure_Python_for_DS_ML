# %% [markdown]
# # Chapter 79: Kaggle Adversarial Validation and Feature Selection

# %% [markdown]
# ## Learning Objectives\n- Detect train/test distribution shift\n- Rank drift-sensitive features\n- Improve OOD robustness via feature ablation

# %%
# !python3 2.adversarial_validation_feature_selection.py
