# %% [markdown]
# 乐学偶得版权所有 lexueoude.com 公众号：乐学Fintech

# %% [markdown]
# 1.Descriptive statistics
# 2.Inferential statistics：
#
# sample(sample statistic) --sampling(estimate)--> population(parameter)
# 1)sampling
# 2)estimate
# 3)Hypothesis test
#
# estimate:
# 1.Point estimation( sample size:n=100 $\overline X =175$)
# 2.Confidence interval（confidence level :95%: $\mu = \overline{X} \pm 1.96 \times S_{\overline{X}}$ ）
# (Z/t) n>30

# %% [markdown]
# $H_{0} : \mu =175 ,\overline{X} =80$

# %% [markdown]
# Hypothesis test:
# 1.
# $H_{0} $ is the Hypothesis you want to reject
# $H_{a} $ is the Hypothesis you want to accept
#
# one tail:
# $H_{0} : \mu \geq 180$
# $H_{a} : \mu < 180$
#
# two tails:
# $H_{0} : \mu = 180$
# $H_{a} : \mu \neq 180$

# %% [markdown]
# 2.Calculation
# $t=\frac{\overline{X} - 180 } { S_{\overline{X} } }$

# %% [markdown]
# 3.Draw distribution:
# one tail: $H_{a} : \mu < 180$

# %% [markdown]
# 4.What is your confidence?

# %% [markdown]
# Using T-Test to test our correlation

# %% [markdown]
# 1.$ H_0: \rho =0 ; H_a :\rho \neq 0$ two tailed test

# %% [markdown]
# 2.Calculate T-statistic:
# $\frac{r-0}{standard Error} =\frac{r-0}{\sqrt{\frac{1-r^2}{n-2}}} $ df=n-2

# %% [markdown]
# ![df.png](attachment:df.png)

# %% [markdown]
# ![t_table.png](attachment:t_table.png)

# %% [markdown]
# ![draw.png](attachment:draw.png)

# %% [markdown]
# 4.The Correlation coefficient between X and Y is significantly different from Zero.

# %% [markdown]
# Limitation:
# 1.Nonlinear Relationship

# %% [markdown]
# ![non_linear.png](attachment:non_linear.png)

# %% [markdown]
# 2.Outlier

# %% [markdown]
# ![outlier.png](attachment:outlier.png)

# %% [markdown]
# 3.Spurious Correlation(1.Chance Relationship 2.Not direct relation)
